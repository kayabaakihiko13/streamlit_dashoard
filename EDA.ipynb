# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
BBRI=yf.Ticker("BBRI.JK")

# %%
BBRI.history_metadata
# Out:
# {'currency': 'IDR',
#  'symbol': 'BBRI.JK',
#  'exchangeName': 'JKT',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1068429600,
#  'regularMarketTime': 1686906891,
#  'gmtoffset': 25200,
#  'timezone': 'WIB',
#  'exchangeTimezoneName': 'Asia/Jakarta',
#  'regularMarketPrice': 5550.0,
#  'chartPreviousClose': 5425.0,
#  'previousClose': 5525.0,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'WIB',
#    'start': 1686879900,
#    'end': 1686880800,
#    'gmtoffset': 25200},
#   'regular': {'timezone': 'WIB',
#    'start': 1686880800,
#    'end': 1686906000,
#    'gmtoffset': 25200},
#   'post': {'timezone': 'WIB',
#    'start': 1686906000,
#    'end': 1686906900,
#    'gmtoffset': 25200}},
#  'tradingPeriods':                                           pre_start                   pre_end  \
#  Date
#  2023-06-12 00:00:00+07:00 2023-06-09 08:45:00+07:00 2023-06-09 09:00:00+07:00
# ...

# %%
print(BBRI.actions)
print(BBRI.splits)
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []
# Series([], Name: Stock Splits, dtype: float64)

# %%
BBRI.HIS

# %%
hist1m = BBRI.history(period="1mo")
hist1m
# Out:
#                              Open    High     Low   Close     Volume  \
# Date
# 2023-05-16 00:00:00+07:00  5175.0  5200.0  5100.0  5200.0   73611200
# 2023-05-17 00:00:00+07:00  5250.0  5250.0  5175.0  5200.0  115834500
# 2023-05-19 00:00:00+07:00  5225.0  5450.0  5200.0  5400.0  185672200
# 2023-05-22 00:00:00+07:00  5300.0  5500.0  5300.0  5425.0  162655900
# 2023-05-23 00:00:00+07:00  5475.0  5600.0  5475.0  5500.0  255251600
# 2023-05-24 00:00:00+07:00  5525.0  5600.0  5450.0  5600.0  187436100
# 2023-05-25 00:00:00+07:00  5500.0  5575.0  5450.0  5475.0  224391900
# 2023-05-26 00:00:00+07:00  5425.0  5600.0  5425.0  5600.0  154003100
# 2023-05-29 00:00:00+07:00  5600.0  5625.0  5475.0  5550.0  125049100
# 2023-05-30 00:00:00+07:00  5500.0  5600.0  5500.0  5500.0   67363200
# 2023-05-31 00:00:00+07:00  5575.0  5575.0  5375.0  5575.0  898453700
# 2023-06-05 00:00:00+07:00  5600.0  5600.0  5425.0  5425.0  255472600
# ...

# %%
data=yf.download("BBRI.JK",start="2020-06-17",end=None)
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close    Adj Close     Volume
# Date
# 2020-06-17  3200.0  3200.0  3080.0  3100.0  2745.745605  218180800
# 2020-06-18  3050.0  3120.0  3040.0  3050.0  2701.459229  130942600
# 2020-06-19  3080.0  3110.0  3060.0  3100.0  2745.745605  166969600
# 2020-06-22  3100.0  3110.0  3030.0  3060.0  2710.316650   95377000
# 2020-06-23  3020.0  3060.0  2980.0  3010.0  2666.030273  171421500
# ...            ...     ...     ...     ...          ...        ...
# 2023-06-12  5400.0  5400.0  5375.0  5400.0  5400.000000   92314200
# 2023-06-13  5400.0  5550.0  5400.0  5550.0  5550.000000  108831400
# 2023-06-14  5575.0  5575.0  5475.0  5550.0  5550.000000   79137600
# 2023-06-15  5475.0  5525.0  5450.0  5525.0  5525.000000   74388400
# 2023-06-16  5475.0  5550.0  5400.0  5550.0  5550.000000  189062600
#
# [731 rows x 6 columns]
